# %% [markdown]
# This file is tested on python 3.11.5

# %%
import sdtm_generators as gs

# %%
sdtm = gs.get_sdtm_data(6,4)

# %%
sdtm['ae']
# Out:
#      PATID    AETERM     AESEV     AESTDTC     AEENDTC  AETOXGR      AEOUT  \
# 0   P00001     Fever    Severe  2024-06-23  2024-07-15  Grade 1  Recovered
# 1   P00001   Fatigue  Moderate  2023-12-28  2023-12-29  Grade 4      Death
# 2   P00001  Headache      Mild  2023-09-19  2023-09-28  Grade 2      Death
# 3   P00001  Headache    Severe  2024-01-11  2024-02-09  Grade 4  Unchanged
# 4   P00002     Fever      Mild  2024-07-24  2024-08-01  Grade 1  Improving
# 5   P00002  Headache    Severe  2023-10-04  2023-10-22  Grade 1  Unchanged
# 6   P00002    Nausea  Moderate  2023-09-28  2023-10-24  Grade 2  Improving
# 7   P00002  Headache      Mild  2024-04-27  2024-04-30  Grade 4   Worsened
# 8   P00002     Fever      Mild  2024-07-07  2024-08-05  Grade 2  Recovered
# 9   P00002      Rash  Moderate  2024-06-07  2024-06-20  Grade 2  Improving
# 10  P00003      Rash    Severe  2023-09-13  2023-09-26  Grade 4  Improving
# ...

# %%
sdtm['cm']
# Out:
#     PATID       CMTRT     CMDOSFRQ CMDOSU     CMSTDTC     CMENDTC
# 0  P00001   Metformin   Once daily     mg  2023-08-16  2024-07-24
# 1  P00002  Amlodipine  Twice daily     mg  2023-12-22  2024-07-28
# 2  P00003   Metformin   Once daily     mg  2024-05-28  2024-07-05
# 3  P00004     Aspirin  Twice daily     mg  2024-04-28  2024-07-18
# 4  P00005   Metformin  Twice daily     mg  2023-11-13  2024-07-12
# 5  P00006  Amlodipine  Twice daily      g  2024-02-02  2024-07-27

# %%
sdtm['dm']
# Out:
#    AGE     SEX      RACE                  ETHNIC     VISITDT   PATID
# 0   57  Female     Black      Hispanic or Latino  2024-02-20  P00001
# 1   32    Male  Hispanic  Not Hispanic or Latino  2023-08-24  P00002
# 2   77  Female     White  Not Hispanic or Latino  2023-11-08  P00003
# 3   20  Female     Asian  Not Hispanic or Latino  2024-02-04  P00004
# 4   18  Female     Asian  Not Hispanic or Latino  2024-06-03  P00005
# 5   90  Female     Asian  Not Hispanic or Latino  2023-09-13  P00006

# %%
sdtm['ex']
# Out:
#     PATID        EXTRT  EXDOSE EXDOSU     EXSTDTC     EXENDTC
# 0  P00001  Treatment A      55     ml  2024-02-06  2024-07-12
# 1  P00002  Treatment A      19     mg  2023-11-28  2024-07-16
# 2  P00003      Placebo      66     mg  2024-05-25  2024-07-08
# 3  P00004      Placebo      65     mg  2024-04-14  2024-08-03
# 4  P00005  Treatment A      98     ml  2024-02-28  2024-07-27
# 5  P00006  Treatment A      73     mg  2023-09-06  2024-08-03

# %%
sdtm['lb']
# Out:
#       PATID       LBTEST LBSTRESU  LBSTRESN LBORRES  VISITNUM    VISIT
# 0    P00001   Hemoglobin     g/dL  2.483354    4.71         1  Visit 1
# 1    P00001  Cholesterol    mg/dL  9.094222    9.47         1  Visit 1
# 2    P00001      Glucose    mg/dL  2.891284    3.56         1  Visit 1
# 3    P00001      Calcium    mg/dL  2.071116    5.80         1  Visit 1
# 4    P00001    Potassium   mmol/L  2.161759    7.48         1  Visit 1
# ..      ...          ...      ...       ...     ...       ...      ...
# 115  P00006   Hemoglobin     g/dL  8.123263    8.85         4  Visit 4
# 116  P00006  Cholesterol    mg/dL  7.143897    3.45         4  Visit 4
# 117  P00006      Glucose    mg/dL  8.487650    8.72         4  Visit 4
# 118  P00006      Calcium    mg/dL  9.663007    7.98         4  Visit 4
# 119  P00006    Potassium   mmol/L  9.417946    6.16         4  Visit 4
#
# [120 rows x 7 columns]

# %%
sdtm['vs']
# Out:
#      PATID          VSTESTCD  VSORRES     VSSTDTC    VISIT
# 0   P00001        Heart Rate       84  2023-10-31  Visit 1
# 1   P00001    Blood Pressure       62  2024-07-08  Visit 1
# 2   P00001  Respiratory Rate       82  2023-09-13  Visit 1
# 3   P00001       Temperature      100  2024-02-18  Visit 1
# 4   P00001        Heart Rate       95  2024-01-24  Visit 2
# ..     ...               ...      ...         ...      ...
# 91  P00006       Temperature       95  2023-09-06  Visit 3
# 92  P00006        Heart Rate       61  2024-04-07  Visit 4
# 93  P00006    Blood Pressure       83  2024-05-20  Visit 4
# 94  P00006  Respiratory Rate       84  2024-04-02  Visit 4
# 95  P00006       Temperature       84  2024-01-14  Visit 4
#
# [96 rows x 5 columns]

# %%
sdtm['rs']
# Out:
#      PATID  VISITNUM             RESPONSE
# 0   P00001         1  Progressive Disease
# 1   P00001         2    Complete Response
# 2   P00001         3       Stable Disease
# 3   P00001         4       Stable Disease
# 4   P00001         5     Partial Response
# 5   P00002         1  Progressive Disease
# 6   P00002         2    Complete Response
# 7   P00002         3     Partial Response
# 8   P00002         4     Partial Response
# 9   P00002         5       Stable Disease
# 10  P00003         1  Progressive Disease
# 11  P00003         2       Stable Disease
# 12  P00003         3       Stable Disease
# 13  P00003         4       Stable Disease
# 14  P00003         5  Progressive Disease
# 15  P00004         1    Complete Response
# 16  P00004         2    Complete Response
# 17  P00004         3     Partial Response
# 18  P00004         4  Progressive Disease
# 19  P00004         5    Complete Response
# 20  P00005         1     Partial Response
# ...
