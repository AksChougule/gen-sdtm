# %%
import sdtm_generators as gs

# %%
sdtm = gs.get_sdtm_data(6,4)

# %%
sdtm['ae']
# Out:
#      PATID     AETERM     AESEV     AESTDTC     AEENDTC  AETOXGR      AEOUT  \
# 0   P00001      Fever      Mild  2023-09-16  2023-10-09  Grade 4      Death
# 1   P00001      Fever      Mild  2023-07-11  2023-07-15  Grade 4  Unchanged
# 2   P00001   Headache    Severe  2022-12-01  2022-12-28  Grade 2  Unchanged
# 3   P00001       Rash      Mild  2023-07-30  2023-08-02  Grade 2  Unchanged
# 4   P00001      Fever  Moderate  2023-11-12  2023-12-11  Grade 3      Death
# 5   P00002    Fatigue      Mild  2023-08-27  2023-09-22  Grade 4  Recovered
# 6   P00002      Fever  Moderate  2023-02-12  2023-03-02  Grade 2  Improving
# 7   P00002   Headache      Mild  2023-10-15  2023-11-13  Grade 2  Recovered
# 8   P00002   Headache  Moderate  2023-02-04  2023-02-19  Grade 2  Unchanged
# 9   P00002  Dizziness    Severe  2022-12-29  2023-01-14  Grade 2   Worsened
# 10  P00003     Nausea      Mild  2023-10-04  2023-10-20  Grade 4  Improving
# ...

# %%
sdtm['cm']
# Out:
#     PATID        CMTRT           CMDOSFRQ CMDOSU     CMSTDTC     CMENDTC
# 0  P00001   Lisinopril  Three times daily     mg  2023-04-13  2023-11-11
# 1  P00002  Simvastatin        Twice daily      g  2023-06-03  2023-10-28
# 2  P00003    Metformin         Once daily      g  2023-02-12  2023-11-12
# 3  P00004  Simvastatin        Twice daily     mg  2022-12-09  2023-11-08
# 4  P00005   Amlodipine  Three times daily     mg  2022-12-11  2023-10-24
# 5  P00006   Lisinopril        Twice daily     mg  2023-04-08  2023-11-11

# %%
sdtm['dm']
# Out:
#    AGE     SEX      RACE                  ETHNIC     VISITDT   PATID
# 0   74    Male     Asian      Hispanic or Latino  2023-04-21  P00001
# 1   57    Male  Hispanic  Not Hispanic or Latino  2023-03-20  P00002
# 2   20    Male     Black      Hispanic or Latino  2023-03-22  P00003
# 3   56  Female     Black  Not Hispanic or Latino  2023-08-19  P00004
# 4   21    Male  Hispanic      Hispanic or Latino  2023-10-03  P00005
# 5   24    Male     Asian  Not Hispanic or Latino  2023-03-20  P00006

# %%
sdtm['ex']
# Out:
#     PATID        EXTRT  EXDOSE EXDOSU     EXSTDTC     EXENDTC
# 0  P00001  Treatment A      48     ml  2023-04-27  2023-10-24
# 1  P00002      Placebo      27     mg  2023-06-14  2023-11-11
# 2  P00003  Treatment A      93     ml  2023-10-07  2023-11-01
# 3  P00004  Treatment A      56     mg  2023-08-02  2023-11-01
# 4  P00005  Treatment A      84     mg  2022-12-27  2023-11-16
# 5  P00006      Placebo      11     ml  2023-03-01  2023-10-29

# %%
sdtm['lb']
# Out:
#       PATID       LBTEST LBSTRESU  LBSTRESN LBORRES  VISITNUM    VISIT
# 0    P00001   Hemoglobin     g/dL  2.559160    5.39         1  Visit 1
# 1    P00001  Cholesterol    mg/dL  7.975369    7.24         1  Visit 1
# 2    P00001      Glucose    mg/dL  4.703007    5.55         1  Visit 1
# 3    P00001      Calcium    mg/dL  4.424643    6.66         1  Visit 1
# 4    P00001    Potassium   mmol/L  9.080288    0.25         1  Visit 1
# ..      ...          ...      ...       ...     ...       ...      ...
# 115  P00006   Hemoglobin     g/dL  2.108652    6.82         4  Visit 4
# 116  P00006  Cholesterol    mg/dL  4.511966    8.66         4  Visit 4
# 117  P00006      Glucose    mg/dL  7.241691    1.63         4  Visit 4
# 118  P00006      Calcium    mg/dL  9.546811    7.68         4  Visit 4
# 119  P00006    Potassium   mmol/L  8.072301    5.86         4  Visit 4
#
# [120 rows x 7 columns]

# %%
sdtm['vs']
# Out:
#      PATID          VSTESTCD  VSORRES     VSSTDTC    VISIT
# 0   P00001        Heart Rate       82  2023-10-24  Visit 1
# 1   P00001    Blood Pressure       85  2023-10-08  Visit 1
# 2   P00001  Respiratory Rate       71  2023-05-26  Visit 1
# 3   P00001       Temperature       97  2023-08-22  Visit 1
# 4   P00001        Heart Rate       69  2023-05-24  Visit 2
# ..     ...               ...      ...         ...      ...
# 91  P00006       Temperature       75  2022-11-30  Visit 3
# 92  P00006        Heart Rate       92  2023-01-17  Visit 4
# 93  P00006    Blood Pressure       71  2023-03-03  Visit 4
# 94  P00006  Respiratory Rate       80  2023-01-21  Visit 4
# 95  P00006       Temperature       63  2023-09-14  Visit 4
#
# [96 rows x 5 columns]

# %%
sdtm['rs']
# Out:
#      PATID  VISITNUM             RESPONSE
# 0   P00001         1    Complete Response
# 1   P00001         2     Partial Response
# 2   P00001         3  Progressive Disease
# 3   P00001         4  Progressive Disease
# 4   P00001         5    Complete Response
# 5   P00002         1     Partial Response
# 6   P00002         2     Partial Response
# 7   P00002         3  Progressive Disease
# 8   P00002         4    Complete Response
# 9   P00002         5       Stable Disease
# 10  P00003         1     Partial Response
# 11  P00003         2     Partial Response
# 12  P00003         3       Stable Disease
# 13  P00003         4  Progressive Disease
# 14  P00003         5     Partial Response
# 15  P00004         1  Progressive Disease
# 16  P00004         2    Complete Response
# 17  P00004         3  Progressive Disease
# 18  P00004         4  Progressive Disease
# 19  P00004         5     Partial Response
# 20  P00005         1    Complete Response
# ...
